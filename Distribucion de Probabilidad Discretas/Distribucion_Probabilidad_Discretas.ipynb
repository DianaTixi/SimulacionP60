# %% [markdown]
# # Practica 7 - Distribucion de Probabilidad Discretas

# %% [markdown]
# Nombre: Diana Fernanda Tixi Uyaguari
#
# Fecha: 01/08/2022

# %% [markdown]
# ###**Una distribución discreta describe la probabilidad de ocurrencia de cada valor de una variable aleatoria discreta. Una variable aleatoria discreta es una variable aleatoria que tiene valores contables, tales como una lista de enteros no negativos.**

# %%
#Librerias
import matplotlib.pyplot as plt
import numpy as np 
from scipy import stats 
import seaborn as sns

# %% [markdown]
#
#
# **Distribución de Hipergeométrica :**
#
# Es una distribución de probabilidad discreta útil para aquellos casos en los que se extraen muestras o en los que hacemos experimentos repetidos sin reemplazo del elemento que hayamos extraído. Vemos, pues, que se ajusta a este problema.
#
#   La Distribución Hipergeométrica esta dada por la formula:
#
#   ![image.png](data:image/png;base64,...)
#
#   Donde:
#   M = cantidad de éxitos posibles en
#   la población
#
#   N= tamaño de población
#
#   n= tamaño de la muestra
#
#   r= valor que toma la variable aleatoria

# %% [markdown]
#   **Ejemplo:** En el equipo hay 8 jugadores que lo hacen en el puesto de alero, dos de los cuales son extranjeros. El entrenador selecciona a dos de ellos para el 5 inicial, ¿cuál es la probabilidad de que uno de ellos sea extranjero?
#
#   Ahora la variable X es el número de jugadores extranjeros elegidos. Dicha variable sigue una H(8,2,0.25), con lo que la probabilidad de que uno sea extranjero es del 42.8%:
#
#
#   **Resultado:**
#
#   p[X=1] = ((2/1)*(6/1)) / (8/2)
#
#   **P[X=5] = 0.428**

# %%
# Graficando Hipergeométrica
M, n, N = 20, 10, 12 
hipergeometrica = stats.hypergeom(M, n, N) # Distribución
x = np.arange(0, n+1)
fmp = hipergeometrica.pmf(x) # Función de Masa de Probabilidad
plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
plt.title('Distribución Hipergeométrica')
plt.ylabel('Probabilidad')
plt.xlabel('Valores')
plt.show()

# %%
# Histograma
aleatorios = hipergeometrica.rvs(1000)  # genera aleatorios
plt.hist(aleatorios, 20)
plt.ylabel('Frecuencia')
plt.xlabel('Valores')
plt.title('Distribución Hipergeométrica')
plt.show()

# %% [markdown]
# _______________________________________

# %% [markdown]
# **Distribución Uniforme:** La distribución uniforme discreta describe el comportamiento de una variable discreta que puede tomar n valores distintos con la misma probabilidad cada uno de ellos. Esta distribución asigna igual probabilidad a todos los valores enteros entre el límite inferior y el límite superior que definen el recorrido de la variable
#
#   La función para el comportamiento de una variable aleatoria discreta con distribución uniforme será:
#
#   ![image.png](data:image/png;base64,...)

# %%
a = 1
b = 20
x = np.arange(a, b + 1)
uniforme_discreta = stats.randint(a, b + 1)

uniforme_discreta_pmf = uniforme_discreta.pmf(x)


plt.plot(x, uniforme_discreta_pmf, 'bo', ms=8)
plt.plot(x, uniforme_discreta_pmf, '--', ms=8)
plt.vlines(x, 0, uniforme_discreta_pmf, colors='b', lw=5, alpha=0.5)
plt.xlabel('Valores')
plt.ylabel('Probabilidad')
plt.title('Distribución Uniforme Discreta')
plt.show()

# %%
# histograma
aleatorios = uniforme_discreta.rvs(1000)  # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 30)
plt.ylabel('Frequencia')
plt.xlabel('Valores')
plt.title('Histograma Distribución Uniforme Discreta')
plt.show()

# %% [markdown]
# ________________________________________

# %% [markdown]
# **Distribución Binomial Negativa :**
#
# La distribución binomial negativa es una distribución que peude considerarse como lo “inverso” de la distribución binoimal. En el contexto binomial, la variable aleatoria X representa el número de éxitos obtenidos en una serie de n ensayo de Bernoulli independientes e idénticos, número que es fijo, mientras que el de éxitos varía de un experimento a otro.
#
#   Formula:
#
#   ![image.png](data:image/png;base64,...)
#
#   Donde:
#
#   x=  = número de ensayos hasta obtener el r-ésimo éxito
#
#  p = la probabilidad de pasar el control de calidad
#
#  r = la cantidad de éxitos

# %% [markdown]
#  * **Ejemplo:** Para el jugador de baloncesto, ¿cuál es la probabilidad de que falle 5 tiros libres antes de conseguir 7 puntos?.
#
#   En este caso la variable X es número de canastas falladas antes del 7º acierto, es decir, se trata de una BN(7,0.8), con lo cual, la probabilidad pedida es:
#
#
#   **Resultado:**
#
#   p[X=5] = ((5+7-1)/5) * (((1-0.8)^5) * (0.8^7)
#
#   **P[X=5] = 0.031**

# %%
x = np.arange(2, 20)
r = 3
p = 0.1

binomial_negativa = stats.nbinom.pmf(x, r, p)

plt.plot(x, binomial_negativa, 'bo', ms=8)
plt.plot(x, binomial_negativa, '--', ms=8)
plt.vlines(x, 0, binomial_negativa, colors='b', lw=5, alpha=0.5)
plt.xlabel('Valores')
plt.ylabel('Probabilidad')
plt.title('Distribución Binomial Negativa')
plt.show()

# %%
# histograma
aleatorios = stats.nbinom.rvs(r, p, size=1000)  # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 10)
plt.ylabel('Frequencia')
plt.xlabel('Valores')
plt.title('Distribución Binomial Negativa')
plt.show()

# %% [markdown]
# # **Referencias:**
#
#
# *   Aguirre Camacho, S. (2016). Clase 6: s/n. Recuperado 1 de agosto de 2022, de https://docplayer.es/22814595-Clase-6-algunas-distribuciones-de-probabilidad-discreta.html
#
# * Distribuciones tipo discreto. (s. f.). s/n. Recuperado 1 de agosto de 2022, de http://www5.uva.es/estadmed/probvar/d_univar/d_univar8.htm
